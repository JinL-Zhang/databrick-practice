# %%
# %sql
-- Bronze layer: Incremental load from volume using COPY INTO
CREATE OR REFRESH STREAMING LIVE TABLE user_query_bronze
COMMENT "Bronze layer - raw user query data from CSV files"
AS SELECT 
  user_query,
  search_result
FROM cloud_files(
  '/Volumes/workspace/default/test_volume/test_directory/',
  'csv',
  map('header', 'true', 'inferSchema', 'true')
)
