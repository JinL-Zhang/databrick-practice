# %%
# %sql
select * from data_pipeline.sale_bronze
Limit 50

# %%
# %sql
select * from data_pipeline.order_bronze
Limit 50

# %%
# %sql
SELECT * FROM data_pipeline.customer_bronze
Limit 50

# %%
# %sql
select * from customers_orders_ca_silver

# %% [markdown]
# ## Check the system.lakeflow that logs all job activity across all workspaces

# %%
# %sql
SHOW SCHEMAS IN system

# %%
# %sql
SHOW TABLES IN system.lakeflow

# %%
# %sql
select jobs.workspace_id, 
        jobs.name as job_name,
        jobs.job_id,
        timeline.run_id,
        timeline.period_start_time,
        timeline.period_end_time,
        timeline.task_key,
        timeline.result_state 
from system.lakeflow.jobs as jobs
inner join 
system.lakeflow.job_task_run_timeline as timeline
on jobs.job_id = timeline.job_id
where jobs.name like "New Job Mar 31%"
order by timeline.period_start_time

# %%
customer_df = spark.table("databricks_simulated_retail_customer_data.v01.customers")

# # Write to a Volume (you need to create the volume first or use an existing one)
volume_path = "/Volumes/workspace/default/test_volume/test_directory/customers.csv"

# # Write as CSV (spark read will accept a folder)
customer_df.coalesce(1).write.mode("overwrite").option("header", "true").csv(volume_path)

# %%
# Get current catalog and schema
current_catalog = spark.sql("SELECT current_catalog()").collect()[0][0]
current_schema = spark.sql("SELECT current_schema()").collect()[0][0]

print(f"Current Catalog: {current_catalog}")
print(f"Current Schema: {current_schema}")
