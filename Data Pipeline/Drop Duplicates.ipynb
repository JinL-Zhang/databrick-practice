# %%
# de-duplicate the table
customer_sales_df = spark.sql("""
                              SELECT DISTINCT * FROM data_pipeline.customer_sales_silver""")

# update the table  
customer_sales_df.write.mode("overwrite").saveAsTable("data_pipeline.customer_sales_silver")
